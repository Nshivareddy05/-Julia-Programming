# %%
# First julia code

println("Hello julia ")
# Out:
# Hello julia

# %%
#Types in julia 

a = 1
b= pi
c="Shiva"
d = true 
e = 3.444

println(typeof(a))
println(typeof(b))
println(typeof(c))
println(typeof(d))
println(typeof(e))
# Out:
# Int64
# Irrational{:π}
# String
# Bool
# Float64

# %%
# Basic Math Operations

x = 2+3*12/4  # Follows the same BODAMAS RULE 
y = x^2
z = sqrt(y)
# Out:
# 11.0

# %%
#Lets go with simple Functions 

function  fun(var)

    return "hello $var"

end

println(fun("shiva"),"\n")

#Some Linear and simple functions 

myname(x) = println(x,"\n")

myname("Shiva")

square_root(x) = sqrt(x)

println(square_root(5))
# Out:
# hello shiva
#
# Shiva
#
# 2.23606797749979

# %%
# Conditional Statements
i =18
if i < 18
    println("Not Eligible for voting")
elseif i==18
    println("Eligible for voting")
end


#Loops

for i in 1:5

    println(i)

end

i = 1

while i <= 5

    print("i= $i \n")
    i+=1

end
# Out:
# Eligible for voting
# 1
# 2
# 3
# 4
# 5
# i= 1
# i= 2
# i= 3
# i= 4
# i= 5
# i= 3
# i= 4
# i= 5

# %%
#simple function 
function even_or_not(x)
    if x%2 == 0
        println("$x is a even number")
    else
        println("$x is not a even number")
    end
end
even_or_not(5)
# Out:
# 5 is not a even number

# %%
#Revise the syntax Buddy

😊 = "All the best bye"

println("$😊 😊")
# Out:
# All the best bye 😊
