# %%
#INDEXING AND SLICING 

A = [1 2 3; 
4 5 6; 
7 8 9]  

println(A[1, 1])

A
# Out:
# 1
# 3×3 Matrix{Int64}:
#  1  2  3
#  4  5  6
#  7  8  9

# %%
A[2, :] #For entire row
# Out:
# 3-element Vector{Int64}:
#  4
#  5
#  6

# %%
A[:,3] # for entire Column
# Out:
# 3-element Vector{Int64}:
#  3
#  6
#  9

# %%
A[:,:] #For Everything
# Out:
# 3×3 Matrix{Int64}:
#  1  2  3
#  4  5  6
#  7  8  9

# %%
#Sub Matrices


A[1:2, 2:3]
# Out:
# 2×2 Matrix{Int64}:
#  2  3
#  5  6

# %%
A = [1 2 3; 4 5 6; 7 8 9]
mask = A .> 5
A[mask]
# Out:
# 4-element Vector{Int64}:
#  7
#  8
#  6
#  9

# %%
A[1, :] .= 0     
A[:, 2] .= 99    
A[1:2, 1:2] .= 1
# Out:
# 2×2 view(::Matrix{Int64}, 1:2, 1:2) with eltype Int64:
#  1  1
#  1  1
